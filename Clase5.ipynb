# %% [markdown]
# <a href="https://colab.research.google.com/github/jsalafica/Data-Science-I/blob/master/Clase5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Generar data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,200)
y = np.tanh(x)

data = pd.DataFrame({'x':x,'y':y})
data.head()

# %%
# que y donde voy a colocar esos datos
plt.figure(figsize=(8,4))

# los datos y que voy colocar
plt.plot(data["x"],data["y"], label="y = tanh(x)", color=(0.1, 0.2, 0.5, 0.3),linestyle=":")
plt.title("Grafico de funcion Tangencial")

# legendas, informacion adicional al grafico
plt.xlabel("Tiempo")
plt.ylabel("Amplitud")

plt.text(5,0.5,r"$\sigma(z) = \frac{e^z - e^{-z}}{e^z + e^{-z}}$")

plt.grid(True, alpha=0.5)
plt.tight_layout(pad=2)
plt.legend()
plt.show()

# %% [markdown]
# Cuadratica

# %%
# Generar datos de entrada
x = np.linspace(-10, 10, 200)  # 200 valores entre -10 y 10

# Definir una relación cuadrática: y = ax^2 + bx + c
a, b, c = 2, -3, 5
y = a * x**2 + b * x + c

cuadradica = pd.DataFrame({'x':x,'y':y})
cuadradica.head()


# Visualizar los datos
plt.figure(figsize=(8, 5))

plt.plot(x, y, label=f"${a}x^2 + {b}x + {c}$")
plt.title("Curva Cuadrática")
plt.xlabel("x")
plt.ylabel("f(y)")
plt.axhline(0, color='gray', linestyle='--')
plt.axvline(0, color='gray', linestyle='--')
plt.legend()
plt.grid(True)
plt.show()

# %%
np.random.seed(42)
x = np.random.rand(50)
y = 2 * x + 1 + np.random.normal(scale=0.1, size=50)

data = pd.DataFrame({'x':x,'y':y})
data.head()

# %%
fig, axes =plt.subplots(1, 3, figsize=(12,4))

axes[0].scatter(data["x"],data["y"], color="darkorange")
axes[0].grid(True)


axes[1].hist(data["y"], bins=10, color="darkorange", alpha=0.7)
axes[1].grid(True)

axes[2].plot(cuadradica.x, cuadradica.y, label=f"${a}x^2 + {b}x + {c}$")
axes[2].set_title("Curva Cuadrática")
axes[2].set_xlabel("x")
axes[2].set_ylabel("f(y)")

plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# Advanced

# %%
football_csv_path = "https://raw.githubusercontent.com/Andru-1987/74235-_DataScience_I/refs/heads/main/clase_5/storage/futbolargentino(Worksheet).csv"

# %%
footbal_dataset = pd.read_csv(football_csv_path,sep=";")

# %%
footbal_dataset.info()

# %%
plt.figure(figsize=(8, 5))
plt.hist(footbal_dataset.Edad, bins=20, color='skyblue', edgecolor='black')

# Etiquetas y título
plt.title("Distribución de edades de jugadores de fútbol")
plt.xlabel("Edad")
plt.ylabel("Cantidad de jugadores")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
