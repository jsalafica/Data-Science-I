# %% [markdown]
# <a href="https://colab.research.google.com/github/jsalafica/Data-Science-I/blob/master/Clase_6/clase6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
url_dataset = "https://raw.githubusercontent.com/jsalafica/Data-Science-I/refs/heads/master/Clase_6/storage/nac_viv_annio__sit_conv_dm_limpio.csv"

# %%
dataframe = pd.read_csv(url_dataset, sep=';')

# %%
dataframe.head()
# Out:
#    anio  cant_nacidos_vivos situacion_convivencia
# 0  2001                1486              Ignorado
# 1  2001                2951            No convive
# 2  2001               37734               Convive
# 3  2002                1261              Ignorado
# 4  2002                2893            No convive

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   anio                   66 non-null     int64
#  1   cant_nacidos_vivos     66 non-null     int64
#  2   situacion_convivencia  66 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 1.7+ KB

# %%
dataframe.describe().T
# Out:
#                     count          mean           std     min     25%     50%  \
# anio                 66.0   2011.500000      6.392905  2001.0  2006.0  2011.5
# cant_nacidos_vivos   66.0  13082.454545  16438.360711   197.0  1313.0  2647.5
#
#                         75%      max
# anio                 2017.0   2022.0
# cant_nacidos_vivos  31863.5  41693.0

# %%
dataframe.describe(include='object').T
# Out:
#                       count unique       top freq
# situacion_convivencia    66      3  Ignorado   22
